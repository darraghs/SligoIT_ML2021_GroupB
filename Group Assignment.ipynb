# %%
import pandas as pd

# %%
opel_1_df = pd.read_csv('data/opel_corsa_01.csv', sep=';')
opel_2_df = pd.read_csv('data/opel_corsa_02.csv', sep=';')
peugeot_1_df = pd.read_csv('data/peugeot_207_01.csv', sep=';')
peugeot_2_df = pd.read_csv('data/peugeot_207_02.csv', sep=';')

# %%
opel_1_df['car'] = 'opel'
opel_1_df['source'] = 'opel_corsa_01.csv'

# %%
opel_2_df['car'] = 'opel'
opel_2_df['source'] = 'opel_corsa_02.csv'

# %%
peugeot_1_df['car'] = 'peugeot'
peugeot_1_df['source'] = 'peugeot_207_01.csv'

# %%
peugeot_2_df['car'] = 'peugeot'
peugeot_2_df['source'] = 'peugeot_207_02.csv'

# %%
peugeot_df = pd.concat([opel_1_df, opel_1_dfpeugeot_1_df, peugeot_2_df])

# %%
peugeot_df
# Out:
#      AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0                  NaN                         0                 NaN
# 1                  NaN                         0                 NaN
# 2                  NaN                         0                 NaN
# 3                  NaN                         0                 NaN
# 4                  NaN                         0                 NaN
# ...                ...                       ...                 ...
# 4618                 1               28,79999924         28,55999908
# 4619       1,699996948               30,59999847          28,5299991
# 4620       1,800003052               29,69999886         28,49999908
# 4621       2,100006104               29,69999886         28,40999908
# 4622               1,5               33,29999924         28,34999911
#
#      VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# ...

# %%
opel_df = pd.concat([opel_1_df, opel_2_df])

# %%
opel_df
# Out:
#      AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0                  NaN                         0                 NaN
# 1                  NaN                         0                 NaN
# 2                  NaN                       NaN                 NaN
# 3                  NaN                       NaN                 NaN
# 4                  NaN                         0                 NaN
# ...                ...                       ...                 ...
# 4323      -2,800003052               64,17630005         57,46968689
# 4324      -2,800003052               63,27557755         57,61605384
# 4325      -2,800003052               62,60003281         57,75491473
# 4326      -2,800003052               62,60003281         57,85999864
# 4327      -2,800003052               61,47413635         57,96508261
#
#      VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# ...

# %%
car_df = pd.concat([opel_df, peugeot_df])

# %%
car_df
# Out:
#      AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0                  NaN                         0                 NaN
# 1                  NaN                         0                 NaN
# 2                  NaN                       NaN                 NaN
# 3                  NaN                       NaN                 NaN
# 4                  NaN                         0                 NaN
# ...                ...                       ...                 ...
# 4618                 1               28,79999924         28,55999908
# 4619       1,699996948               30,59999847          28,5299991
# 4620       1,800003052               29,69999886         28,49999908
# 4621       2,100006104               29,69999886         28,40999908
# 4622               1,5               33,29999924         28,34999911
#
#      VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# ...

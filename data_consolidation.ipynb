# %%
## Libraries
import numpy as np
import pandas as pd

# %%
## Read in CSV

opal_corsa_01 = pd.read_csv("opel_corsa_01.csv", sep = ';')
opal_corsa_01["Make"] = "Opal Corsa"
opal_corsa_01["Source File"] = 1


opal_corsa_02 = pd.read_csv("opel_corsa_02.csv", sep = ';')
opal_corsa_02["Make"] = "Opal Corsa"
opal_corsa_02["Source File"] = 2

peugeot_207_01 = pd.read_csv("peugeot_207_01.csv", sep = ';')
peugeot_207_01["Make"] = "Peugeot 207"
peugeot_207_01["Source File"] = 1

peugeot_207_02 = pd.read_csv("peugeot_207_01.csv", sep = ';')
peugeot_207_02["Make"] = "Peugeot 207"
peugeot_207_02["Source File"] = 2

dataset = [opal_corsa_01, opal_corsa_02, peugeot_207_01, peugeot_207_02]

combined = pd.concat(dataset)

data_pre_cleaning = combined.drop('Unnamed: 0', axis = 1)

data_pre_cleaning.describe()

data_pre_cleaning.to_csv("pre_cleaning_dataset.csv",index = False)

# %%
data_pre_cleaning = data_pre_cleaning.replace('SmoothCondition', 1)
data_pre_cleaning = data_pre_cleaning.replace('UnevenCondition', 0)
data_pre_cleaning = data_pre_cleaning.replace('FullOfHolesCondition', 2)
# Out:
# (27528, 19)

# %%
data_pre_cleaning.describe()
# Out:
#        AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# count       27528.000000               27522.000000         27528.000000
# mean           -0.293105                  43.551822            43.774668
# std             2.184547                  35.695948            33.060156
# min           -24.600006                   0.000000             0.000000
# 25%            -1.500000                  14.861880            18.077400
# 50%            -0.199997                  36.000000            33.539999
# 75%             0.700012                  63.899998            60.598750
# max            10.700012                 124.749725           121.330733
#
#        VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# count          27528.000000           27528.000000              27528.000000
# mean             173.723456              -0.021700                  0.946825
# std              190.952655               2.595848                  1.457305
# min                0.000000            -103.500000                 -2.380000
# 25%               44.289176              -0.900002                  0.099200
# 50%              111.936149               0.000000                  0.785100
# 75%              232.502979               0.900002                  1.450700
# max             1418.370369              97.199997                  8.477800
#
#          EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# count  27518.000000              27518.000000              27518.000000
# mean      38.752831                 71.452068                116.769678
# std       28.328987                 15.432489                 20.459072
# min        0.000000                 12.000000                 88.000000
# 25%       18.431374                 67.000000                103.000000
# 50%       31.372549                 79.000000                108.000000
# 75%       67.058823                 80.000000                126.000000
# max      100.000000                 89.000000                252.000000
#
#           EngineRPM   MassAirFlow  IntakeAirTemperature  VerticalAcceleration  \
# count  27518.000000  27518.000000          27518.000000          27528.000000
# mean    1553.219129     17.070594             27.045825              0.231125
# std      592.953299      9.810971             12.526414              3.268192
# min        0.000000      0.880000              7.000000             -2.763100
# 25%      941.625000      7.852500             17.000000             -0.783000
# 50%     1557.500000     16.490000             22.000000             -0.248600
# 75%     2059.000000     23.830000             37.000000              0.164100
# max     3167.000000     73.250000             65.000000             17.944800
#
#        FuelConsumptionAverage   Source File
# count            27518.000000  27528.000000
# mean                14.271932      1.446491
# std                  4.324763      0.497138
# min                  7.271883      1.000000
# 25%                 10.681483      1.000000
# 50%                 13.769330      1.000000
# 75%                 16.677401      2.000000
# max                 45.336861      2.000000
